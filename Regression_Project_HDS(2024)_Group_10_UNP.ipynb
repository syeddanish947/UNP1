# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # UPLOADING DATASET

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-40b109ce-a064-4332-a170-35a757423670" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-40b109ce-a064-4332-a170-35a757423670">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('/content/student-por.csv')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# # CHECKING FOR NULL VALUES

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.shape
# Out:
# (649, 33)

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
df.dropna(inplace=True)

# %%
df=df.drop('G1',axis=1)
df=df.drop('G2',axis=1)

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G3'],
#       dtype='object')

# %%
df['school'] = df['school'].map({'GP': 0, 'MS': 1})
df['sex'] = df['sex'].map({'F': 0, 'M': 1})
df['address'] = df['address'].map({'U': 0, 'R': 1})
df['famsize'] = df['famsize'].map({'LE3': 0, 'GT3': 1})
df['Pstatus'] = df['Pstatus'].map({'T': 0, 'A': 1})
df['schoolsup'] = df['schoolsup'].map({'no': 0, 'yes': 1})
df['famsup'] = df['famsup'].map({'no': 0, 'yes': 1})
df['paid'] = df['paid'].map({'no': 0, 'yes': 1})
df['activities'] = df['activities'].map({'no': 0, 'yes': 1})
df['nursery'] = df['nursery'].map({'no': 0, 'yes': 1})
df['higher'] = df['higher'].map({'no': 0, 'yes': 1})
df['internet'] = df['internet'].map({'no': 0, 'yes': 1})
df['romantic'] = df['romantic'].map({'no': 0, 'yes': 1})

# %%
data_with_dummies = pd.get_dummies(df, columns=['Mjob', 'Fjob', 'reason', 'guardian'], drop_first=True)
data_with_dummies=data_with_dummies.replace({True: 1, False: 0})
print("Data with Dummy Variables:",data_with_dummies)
# Out:
# Data with Dummy Variables:      school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0         0    0   18        0        1        1     4     4           2
# 1         0    0   17        0        1        0     1     1           1
# 2         0    0   15        0        0        0     1     1           1
# 3         0    0   15        0        1        0     4     2           1
# 4         0    0   16        0        1        0     3     3           1
# ..      ...  ...  ...      ...      ...      ...   ...   ...         ...
# 644       1    0   19        1        1        0     2     3           1
# 645       1    0   18        0        0        0     3     1           1
# 646       1    0   18        0        1        0     1     1           2
# 647       1    1   17        0        0        0     3     1           2
# 648       1    1   18        1        0        0     3     2           3
#
# ...

# %%
data_with_dummies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   school             649 non-null    int64
#  1   sex                649 non-null    int64
#  2   age                649 non-null    int64
#  3   address            649 non-null    int64
#  4   famsize            649 non-null    int64
#  5   Pstatus            649 non-null    int64
#  6   Medu               649 non-null    int64
#  7   Fedu               649 non-null    int64
#  8   traveltime         649 non-null    int64
#  9   studytime          649 non-null    int64
#  10  failures           649 non-null    int64
#  11  schoolsup          649 non-null    int64
#  12  famsup             649 non-null    int64
#  13  paid               649 non-null    int64
#  14  activities         649 non-null    int64
#  15  nursery            649 non-null    int64
# ...

# %%
data_with_dummies.iloc[:,7].value_counts()
# Out:
# Fedu
# 2    209
# 1    174
# 3    131
# 4    128
# 0      7
# Name: count, dtype: int64

# %%
for i in range(data_with_dummies.shape[1]):
  print(data_with_dummies.iloc[:,i].unique())
  print(data_with_dummies.iloc[:,i].value_counts())
# Out:
# [0 1]
# school
# 0    423
# 1    226
# Name: count, dtype: int64
# [0 1]
# sex
# 0    383
# 1    266
# Name: count, dtype: int64
# [18 17 15 16 19 22 20 21]
# age
# 17    179
# 16    177
# 18    140
# 15    112
# 19     32
# 20      6
# 21      2
# 22      1
# Name: count, dtype: int64
# [0 1]
# address
# 0    452
# 1    197
# Name: count, dtype: int64
# [1 0]
# famsize
# 1    457
# 0    192
# Name: count, dtype: int64
# [1 0]
# Pstatus
# 0    569
# 1     80
# Name: count, dtype: int64
# [4 1 3 2 0]
# Medu
# 2    186
# 4    175
# 1    143
# 3    139
# 0      6
# Name: count, dtype: int64
# [4 1 2 3 0]
# Fedu
# 2    209
# 1    174
# 3    131
# 4    128
# 0      7
# Name: count, dtype: int64
# [2 1 3 4]
# traveltime
# 1    366
# 2    213
# 3     54
# 4     16
# Name: count, dtype: int64
# [2 3 1 4]
# studytime
# 2    305
# 1    212
# 3     97
# 4     35
# Name: count, dtype: int64
# [0 3 1 2]
# failures
# 0    549
# 1     70
# 2     16
# 3     14
# Name: count, dtype: int64
# [1 0]
# ...

# %%
data_with_dummies.iloc[:,7].value_counts()
# Out:
# Fedu
# 2    209
# 1    174
# 3    131
# 4    128
# 0      7
# Name: count, dtype: int64

# %%
for i in range(data_with_dummies.shape[1]):
  print(data_with_dummies.iloc[:,i].value_counts())
# Out:
# school
# 0    423
# 1    226
# Name: count, dtype: int64
# sex
# 0    383
# 1    266
# Name: count, dtype: int64
# age
# 17    179
# 16    177
# 18    140
# 15    112
# 19     32
# 20      6
# 21      2
# 22      1
# Name: count, dtype: int64
# address
# 0    452
# 1    197
# Name: count, dtype: int64
# famsize
# 1    457
# 0    192
# Name: count, dtype: int64
# Pstatus
# 0    569
# 1     80
# Name: count, dtype: int64
# Medu
# 2    186
# 4    175
# 1    143
# 3    139
# 0      6
# Name: count, dtype: int64
# Fedu
# 2    209
# 1    174
# 3    131
# 4    128
# 0      7
# Name: count, dtype: int64
# traveltime
# 1    366
# 2    213
# 3     54
# 4     16
# Name: count, dtype: int64
# studytime
# 2    305
# 1    212
# 3     97
# 4     35
# Name: count, dtype: int64
# failures
# 0    549
# 1     70
# 2     16
# 3     14
# Name: count, dtype: int64
# schoolsup
# 0    581
# 1     68
# Name: count, dtype: int64
# famsup
# 1    398
# 0    251
# Name: count, dtype: int64
# paid
# 0    610
# ...

# %%
print(data_with_dummies)
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  \
# 0         0    0   18        0        1        1     4     4           2
# 1         0    0   17        0        1        0     1     1           1
# 2         0    0   15        0        0        0     1     1           1
# 3         0    0   15        0        1        0     4     2           1
# 4         0    0   16        0        1        0     3     3           1
# ..      ...  ...  ...      ...      ...      ...   ...   ...         ...
# 644       1    0   19        1        1        0     2     3           1
# 645       1    0   18        0        0        0     3     1           1
# 646       1    0   18        0        1        0     1     1           2
# 647       1    1   17        0        0        0     3     1           2
# 648       1    1   18        1        0        0     3     2           3
#
#      studytime  ...  Mjob_teacher  Fjob_health  Fjob_other  Fjob_services  \
# ...

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data_with_dummies['G3'], bins=10, kde=True, color='blue')
plt.title('Histogram of G3')
plt.xlabel('G3 Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

plt.figure(figsize=(5, 5))
sns.histplot(data_with_dummies['absences'], bins=10, kde=True, color='blue')
plt.title('Histogram of Absences')
plt.xlabel('Absences')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
corr_matrix =data_with_dummies.corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.show()

# %%
sns.countplot(data_with_dummies['G3'])
plt.title('Distribution of the Target Variable')
plt.show()

# %%
X = df.drop(columns=['G3'])
y = df['G3']

# Display the shapes of X and y to ensure they are correct
print(X.shape)
print(y.shape)
# Out:
# (649, 30)
# (649,)

# %%
plt.figure(figsize=(10,10))
plt.subplot(2, 2, 1)
df['reason'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, cmap='autumn')
plt.title('Reason for Choosing School')
plt.show


health_labels = {1: 'Very Poor', 2: 'Poor', 3: 'Average', 4: 'Good', 5: 'Very Good'}

# Count the frequency of each health level
health_counts = df['health'].value_counts().sort_index()

# Create a pie chart with custom labels
plt.figure(figsize=(8, 6))
plt.pie(
    health_counts,
    labels=[health_labels[key] for key in health_counts.index],
    autopct='%1.1f%%',
    startangle=90,
    colors=['red', 'orange', 'yellow', 'green', 'blue']
)
plt.title('Health Status Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.scatter(df['age'], df['G3'])
plt.xlabel('Age')
plt.ylabel('G3')
plt.title('Scatter Plot: Age vs G3')
plt.show()
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 2)
plt.scatter(df['studytime'], df['G3'])
plt.xlabel('Study Time')
plt.ylabel('G3')
plt.title('Scatter Plot: Study Time vs G3')
plt.show()
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 3)
plt.scatter(df['failures'], df['G3'])
plt.xlabel('Failures')
plt.ylabel('G3')
plt.title('Scatter Plot: Failures vs G3')
plt.show()
plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 4)
plt.scatter(df['absences'], df['G3'])
plt.xlabel('Absences')
plt.ylabel('G3')
plt.title('Scatter Plot: Absences vs G3')
# Out:
# Text(0.5, 1.0, 'Scatter Plot: Absences vs G3')

# %%
plt.figure(figsize=(15, 10))
plt.subplot(2, 2, 1)
df['guardian'].value_counts().plot(kind='bar')
plt.title('Frequency Plot of Guardian')

plt.subplot(2, 2, 2)
df['Mjob'].value_counts().plot(kind='bar')
plt.title('Frequency Plot of Mother\'s Job')

plt.subplot(2, 2, 3)
df['Fjob'].value_counts().plot(kind='bar')
plt.title('Frequency Plot of Father\'s Job')

plt.tight_layout()
plt.show()

# %%
# Step: Box Plots for Selected Numerical Variables
plt.figure(figsize=(15, 10))
# Box plot for 'studytime'
plt.subplot(2, 3, 1)
sns.boxplot(y=df['studytime'])
plt.title('Box Plot of Study Time')
plt.ylabel('Study Time')


# Box plot for 'absences'
plt.subplot(2, 3, 2)
sns.boxplot(y=df['absences'])
plt.title('Box Plot of Absences')
plt.ylabel('Absences')

# Box plot for 'age'
plt.subplot(2, 3, 3)
sns.boxplot(y=df['age'])
plt.title('Box Plot of Age')
plt.ylabel('Age')

# Box plot for 'health'
plt.subplot(2, 3, 4)
sns.boxplot(y=df['health'])
plt.title('Box Plot of Health Status')
plt.ylabel('Health Status')

# Box plot for 'goout'
plt.subplot(2, 3, 5)
sns.boxplot(y=df['goout'])
plt.title('Box Plot of Going Out Frequency')
plt.ylabel('Going Out Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
X = data_with_dummies.drop(columns=['G3'])
y=data_with_dummies['G3']

# %% [markdown]
# # TRAIN TEST SPLIT

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.20, train_size=0.80,random_state=0)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size=0.25, train_size=0.75,random_state=0)
X_train3, X_test3, y_train3, y_test3 = train_test_split(X, y, test_size=0.30, train_size=0.70,random_state=0)
X_train4, X_test4, y_train4, y_test4 = train_test_split(X, y, test_size=0.40, train_size=0.60,random_state=0)

# %% [markdown]
# # 80-20 SPLIT

# %%
lm=LinearRegression()
lm.fit(X_train1, y_train1)
y_pred1 =lm.predict(X_test1)
print("MAE:",metrics.mean_absolute_error(y_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_test1,y_pred1))
# Out:
# MAE: 1.6815805365982481
# RMSE: 2.394743885744263
# R2 score: 0.1927259703519103

# %% [markdown]
# # 75-25 SPLIT

# %%
lm=LinearRegression()
lm.fit(X_train2, y_train2)
y_pred2 =lm.predict(X_test2)
print("MAE:",metrics.mean_absolute_error(y_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_test2,y_pred2))
# Out:
# MAE: 1.8336201052578964
# RMSE: 2.6447534845706673
# R2 score: 0.2250417326486116

# %% [markdown]
# # 70-30 SPLIT

# %%
lm=LinearRegression()
lm.fit(X_train3, y_train3)
y_pred3 =lm.predict(X_test3)
print("MAE:",metrics.mean_absolute_error(y_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_test3,y_pred3))
# Out:
# MAE: 1.8766437684625912
# RMSE: 2.6699151198210744
# R2 score: 0.2740315725795306

# %% [markdown]
# # 60-40 SPLIT

# %%
lm=LinearRegression()
lm.fit(X_train4, y_train4)
y_pred4 =lm.predict(X_test4)
print("MAE:",metrics.mean_absolute_error(y_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_test4,y_pred4))
# Out:
# MAE: 2.1303930600184073
# RMSE: 3.073507542251163
# R2 score: 0.1707303461851548

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# # (80-20) SPLIT

# %%
model1=KNeighborsRegressor(n_neighbors=25)
model1.fit(X_train1, y_train1)
# Out:
# KNeighborsRegressor(n_neighbors=25)

# %%
y_pred1 = model1.predict(X_test1)
y_pred1
# Out:
# array([11.64, 12.72, 12.72, 12.88, 11.4 , 13.  , 13.84, 13.52, 12.72,
#        12.44, 11.56, 11.2 , 12.16, 13.16, 14.64, 14.16, 12.92, 14.56,
#        12.6 , 12.76, 13.04, 12.12, 14.64, 14.04, 12.56, 13.12, 13.76,
#        11.72, 13.76, 11.16, 12.76, 12.32, 11.6 , 13.28, 11.56, 12.64,
#        11.56, 13.48, 12.12, 12.6 , 13.  , 12.4 ,  9.76, 13.68, 13.  ,
#        11.  , 11.8 , 12.36, 12.04, 13.44, 12.16, 14.36, 11.52, 12.56,
#        11.32, 10.8 , 13.12, 10.8 , 13.88, 12.36, 13.64, 10.6 , 11.68,
#        10.88, 13.32, 13.44, 13.64, 13.72, 12.56, 13.12, 12.16, 13.28,
#        11.48, 15.08, 12.6 , 12.68, 12.84, 13.  , 13.8 , 12.36, 13.72,
#        12.72, 12.2 , 13.64, 14.32, 13.4 , 10.96, 12.08, 12.76, 12.4 ,
#        10.72, 13.52, 12.8 , 10.56, 10.8 , 10.04, 11.84, 13.36, 13.32,
#        12.6 , 13.36, 11.6 , 12.76, 12.92, 13.12, 11.12, 12.92, 10.36,
#        13.16, 13.48, 13.4 , 13.68, 13.72, 12.36, 13.96, 10.32,  9.52,
# ...

# %%
knn1 = pd.DataFrame({'Predicted':y_pred1,'Actual':y_test1})
knn1
# Out:
#      Predicted  Actual
# 532      11.64       8
# 375      12.72      15
# 306      12.72      16
# 625      12.88      10
# 480      11.40      10
# ..         ...     ...
# 403      11.84      15
# 266      13.24      14
# 641      12.32      15
# 558       9.72      10
# 242      11.44      11
#
# [130 rows x 2 columns]

# %% [markdown]
#  EVALUATION METRICS FOR (80-20) SPLIT

# %%
print("R2 SCORE:")
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred1)
# Out:
# R2 SCORE:
# 0.09004677817018747

# %%
print("MAE:")
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test1,y_pred1)
# Out:
# MAE:
# 1.9341538461538461

# %%
print("MSE:")
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test1,y_pred1)
# Out:
# MSE:
# 6.464221538461538

# %%
print("RMSE:")
mse = mean_squared_error(y_test1, y_pred1)
rmse = np.sqrt(mse)
rmse
# Out:
# RMSE:
# 2.54248334084248

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test1, y_pred1)
print(mape)
mape = mape * 100
mape
# Out:
# 454517131623853.25
# 4.545171316238533e+16

# %%
plt.scatter(X_test1['absences'], y_test1, label='Test Data')
plt.scatter(X_test1['absences'], y_pred1, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# # (75-25) SPLIT

# %%
model2=KNeighborsRegressor(n_neighbors=25)
model2.fit(X_train2, y_train2)
# Out:
# KNeighborsRegressor(n_neighbors=25)

# %%
y_pred2 = model2.predict(X_test2)
y_pred2
# Out:
# array([11.64, 13.04, 12.24, 12.68, 11.32, 12.84, 13.92, 13.64, 12.6 ,
#        12.76, 11.48, 11.32, 12.28, 13.08, 14.48, 13.68, 13.  , 14.32,
#        12.76, 12.6 , 13.24, 12.16, 14.96, 14.  , 12.2 , 14.08, 13.64,
#        11.4 , 13.72, 11.12, 12.84, 12.28, 11.6 , 13.28, 11.44, 12.12,
#        11.68, 13.48, 12.2 , 12.48, 12.8 , 12.44, 10.04, 13.64, 12.72,
#        10.96, 11.76, 12.72, 12.4 , 13.52, 11.56, 14.32, 11.48, 12.76,
#        11.32, 10.64, 12.8 , 10.76, 13.64, 12.28, 13.4 , 10.4 , 11.48,
#        10.48, 12.76, 13.72, 13.12, 13.32, 12.08, 13.04, 12.56, 13.64,
#        11.36, 14.84, 12.68, 12.52, 12.92, 13.08, 14.04, 12.36, 13.76,
#        13.2 , 11.36, 13.56, 14.04, 13.4 , 10.84, 11.56, 12.48, 12.24,
#        11.  , 13.6 , 12.72, 10.56, 10.64, 10.  , 11.84, 13.  , 13.36,
#        12.72, 13.76, 11.6 , 12.32, 13.  , 13.88, 10.96, 12.96, 10.52,
#        13.2 , 13.52, 13.76, 13.4 , 13.4 , 12.32, 13.68, 10.12,  9.4 ,
# ...

# %%
knn2 = pd.DataFrame({'Predicted':y_pred2,'Actual':y_test2})
knn2
# Out:
#      Predicted  Actual
# 532      11.64       8
# 375      13.04      15
# 306      12.24      16
# 625      12.68      10
# 480      11.32      10
# ..         ...     ...
# 588      13.08       9
# 332      14.04      18
# 202      11.96      14
# 316      13.12      16
# 90       13.48      11
#
# [163 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS FOR (75-25) SPLIT

# %%
print("R2 SCORE:")
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred2)
# Out:
# R2 SCORE:
# 0.12342119511279759

# %%
print("MAE:")
from sklearn import metrics
metrics.mean_absolute_error(y_test2,y_pred2)
# Out:
# MAE:
# 2.0581595092024543

# %%
print("MSE:")
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test2,y_pred2)
# Out:
# MSE:
# 7.911941104294479

# %%
print("RMSE:")
mse2 = mean_squared_error(y_test2, y_pred2)
rmse2 = np.sqrt(mse2)
rmse2
# Out:
# RMSE:
# 2.81281728953277

# %%
print("MAPE:")
from sklearn.metrics import mean_absolute_percentage_error
mape2 = mean_absolute_percentage_error(y_test2, y_pred2)
print(mape2)
mape2 = mape2 * 100
mape2
# Out:
# MAPE:
# 999080751691516.1
# 9.990807516915162e+16

# %%
plt.scatter(X_test2['absences'], y_test2, label='Test Data')
plt.scatter(X_test2['absences'], y_pred2, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# #  (70-30) SPLIT

# %%
model3=KNeighborsRegressor(n_neighbors=25)
model3.fit(X_train3, y_train3)
y_pred3 = model3.predict(X_test3)
y_pred3
# Out:
# array([11.64, 13.12, 12.08, 12.68, 11.48, 12.68, 13.8 , 13.44, 12.64,
#        13.04, 11.68, 11.2 , 12.52, 13.04, 14.48, 13.68, 13.04, 14.32,
#        12.76, 12.72, 13.24, 11.96, 14.68, 14.52, 12.08, 14.12, 13.8 ,
#        11.4 , 13.8 , 11.52, 12.84, 12.48, 11.6 , 13.28, 10.96, 11.76,
#        11.68, 13.52, 12.28, 13.  , 12.8 , 12.48, 10.16, 12.88, 12.92,
#        11.08, 12.12, 12.56, 12.4 , 13.04, 11.56, 14.2 , 11.52, 12.72,
#        11.  , 10.36, 12.92, 10.44, 13.96, 12.56, 12.96, 10.96, 11.8 ,
#        10.84, 13.08, 13.48, 14.04, 13.32, 12.96, 13.04, 12.6 , 13.48,
#        11.44, 14.84, 12.68, 12.76, 13.08, 13.24, 14.  , 12.2 , 13.96,
#        12.88, 11.44, 13.56, 14.16, 13.52, 10.56, 11.64, 12.52, 12.16,
#        10.68, 13.64, 13.  , 11.28, 10.36,  9.64, 11.88, 13.16, 13.2 ,
#        12.4 , 13.68, 11.56, 12.  , 13.04, 12.28, 10.76, 13.12, 10.8 ,
#        13.  , 13.4 , 13.8 , 13.4 , 13.6 , 12.32, 13.48, 10.12, 10.  ,
# ...

# %%
knn3 = pd.DataFrame({'Predicted':y_pred3,'Actual':y_test3})
knn3
# Out:
#      Predicted  Actual
# 532      11.64       8
# 375      13.12      15
# 306      12.08      16
# 625      12.68      10
# 480      11.48      10
# ..         ...     ...
# 478      11.60       8
# 636      12.76      19
# 632      12.08       9
# 96       13.52      11
# 350      11.80      11
#
# [195 rows x 2 columns]

# %% [markdown]
#  EVALUATION METRICS FOR (70-30) SPLIT

# %%
print("R2 SCORE:")
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred3)
# Out:
# R2 SCORE:
# 0.14637112187178614

# %%
print("MAE:")
from sklearn import metrics
metrics.mean_absolute_error(y_test3,y_pred3)
# Out:
# MAE:
# 2.111794871794872

# %%
print("MSE:")
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test3,y_pred3)
# Out:
# MSE:
# 8.381973333333333

# %%
print("RMSE:")
mse3 = mean_squared_error(y_test3, y_pred3)
rmse3 = np.sqrt(mse3)
rmse3
# Out:
# RMSE:
# 2.8951637835074777

# %%
print("MAPE:")
from sklearn.metrics import mean_absolute_percentage_error
mape3 = mean_absolute_percentage_error(y_test3, y_pred3)
print(mape3)
mape3 = mape3 * 100
mape3
# Out:
# MAPE:
# 849910083524278.5
# 8.499100835242786e+16

# %%
plt.scatter(X_test3['absences'], y_test3, label='Test Data')
plt.scatter(X_test3['absences'], y_pred3, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# # (60-40) SPLIT

# %%
model4=KNeighborsRegressor(n_neighbors=25)
model4.fit(X_train4, y_train4)
# Out:
# KNeighborsRegressor(n_neighbors=25)

# %%
y_pred4 = model4.predict(X_test4)
y_pred4
# Out:
# array([12.28, 12.92, 12.24, 12.28, 12.04, 13.04, 13.52, 13.48, 13.04,
#        13.24, 11.64, 11.  , 12.6 , 13.36, 14.04, 14.  , 13.04, 13.88,
#        12.68, 13.2 , 13.  , 12.  , 14.6 , 13.76, 12.56, 13.24, 13.72,
#        10.76, 14.04, 11.68, 12.48, 11.8 , 12.08, 13.28, 10.96, 12.08,
#        11.8 , 13.52, 12.08, 13.36, 12.12, 13.16, 10.04, 13.52, 12.72,
#        11.32, 11.92, 12.88, 12.44, 13.2 , 11.8 , 14.52, 11.52, 12.88,
#        11.2 , 10.96, 13.28, 10.8 , 14.  , 12.44, 13.28, 11.16, 11.52,
#        11.04, 13.16, 13.84, 13.92, 13.4 , 12.96, 13.72, 13.04, 13.  ,
#        12.08, 14.36, 12.56, 12.2 , 12.96, 13.4 , 14.08, 12.88, 14.12,
#        12.64, 11.76, 13.36, 13.92, 14.  , 11.08, 12.2 , 12.52, 12.56,
#        11.32, 13.16, 12.96, 11.48, 10.84,  9.72, 11.84, 13.08, 13.28,
#        12.04, 13.6 , 11.68, 11.84, 13.08, 12.88, 10.88, 13.92, 10.8 ,
#        13.36, 13.12, 13.72, 13.52, 13.44, 12.48, 13.64, 10.04, 10.28,
# ...

# %%
knn4 = pd.DataFrame({'Predicted':y_pred4,'Actual':y_test4})
knn4
# Out:
#      Predicted  Actual
# 532      12.28       8
# 375      12.92      15
# 306      12.24      16
# 625      12.28      10
# 480      12.04      10
# ..         ...     ...
# 140      12.08      10
# 587      12.16       8
# 225      11.32      12
# 536      11.56      14
# 605       9.88       0
#
# [260 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS FOR (60-40) SPLIT

# %%
print("R2 SCORE:")
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred4)
# Out:
# R2 SCORE:
# 0.12123065095688468

# %%
print("MAE:")
from sklearn import metrics
metrics.mean_absolute_error(y_test4,y_pred4)
# Out:
# MAE:
# 2.2910769230769232

# %%
print("MSE:")
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test4,y_pred4)
# Out:
# MSE:
# 10.010313846153847

# %%
print("RME:")
mse4 = mean_squared_error(y_test4, y_pred4)
rmse4 = np.sqrt(mse4)
rmse4
# Out:
# RME:
# 3.1639080021634394

# %%
print("MAPE:")
from sklearn.metrics import mean_absolute_percentage_error
mape4 = mean_absolute_percentage_error(y_test4, y_pred4)
print(mape4)
mape4 = mape4 * 100
mape4
# Out:
# MAPE:
# 1416901728918871.8
# 1.4169017289188717e+17

# %%
plt.scatter(X_test3['absences'], y_test3, label='Test Data')
plt.scatter(X_test3['absences'], y_pred3, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR

# %% [markdown]
# # (80-20) SPLIT

# %%
model1 = SVR(kernel='rbf')
model1.fit(X_train1, y_train1)
# Out:
# SVR()

# %%
y_pred1=model1.predict(X_test1)

# %%
svm1 = pd.DataFrame({'Predicted':y_pred1,'Actual':y_test1})
svm1
# Out:
#      Predicted  Actual
# 532  11.379767       8
# 375  11.970851      15
# 306  11.867105      16
# 625  12.005019      10
# 480  11.439180      10
# ..         ...     ...
# 403  11.100451      15
# 266  12.865722      14
# 641  12.005810      15
# 558  10.128166      10
# 242  10.918044      11
#
# [130 rows x 2 columns]

# %% [markdown]
#  EVALUATION METRICS (80-20) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_test1,y_pred1))
# Out:
# MAE: 1.7996203512860536
# RMSE: 2.437156633907353
# R2 score: 0.1638778691314332

# %%
plt.scatter(X_test1['absences'], y_test1, label='Test Data')
plt.scatter(X_test1['absences'], y_pred1, color='red', linewidth=1, label='SVM points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# # (75-25) SPLIT

# %%
model2 = SVR(kernel='rbf')
model2.fit(X_train2, y_train2)
# Out:
# SVR()

# %%
y_pred2=model2.predict(X_test2)
svm2 = pd.DataFrame({'Predicted':y_pred2,'Actual':y_test2})
svm2
# Out:
#      Predicted  Actual
# 532  11.450085       8
# 375  11.898579      15
# 306  11.827092      16
# 625  12.032568      10
# 480  11.471033      10
# ..         ...     ...
# 588  12.398056       9
# 332  12.784493      18
# 202  11.527710      14
# 316  12.279269      16
# 90   12.828017      11
#
# [163 rows x 2 columns]

# %% [markdown]
#  EVALUATION METRICS FOR (75-25) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_test2,y_pred2))
# Out:
# MAE: 1.9742001348486533
# RMSE: 2.7641513880490463
# R2 score: 0.15349101991057656

# %%
plt.scatter(X_test2['absences'], y_test2, label='Test Data')
plt.scatter(X_test2['absences'], y_pred2, color='red', linewidth=1, label='SVM points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# # (70-30) SPLIT

# %%
model3 = SVR(kernel='rbf')
model3.fit(X_train3, y_train3)
# Out:
# SVR()

# %%
y_pred3=model3.predict(X_test3)
svm3 = pd.DataFrame({'Predicted':y_pred3,'Actual':y_test3})
svm3
# Out:
#      Predicted  Actual
# 532  11.462994       8
# 375  12.023462      15
# 306  11.902556      16
# 625  12.113057      10
# 480  11.754626      10
# ..         ...     ...
# 478  11.052971       8
# 636  12.636809      19
# 632  11.122431       9
# 96   11.991712      11
# 350  11.905894      11
#
# [195 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS FOR (70-30) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_test3,y_pred3))
# Out:
# MAE: 2.0618948264989867
# RMSE: 2.8588210587402614
# R2 score: 0.16766766050783832

# %%
plt.scatter(X_test3['absences'], y_test3, label='Test Data')
plt.scatter(X_test3['absences'], y_pred3, color='red', linewidth=1, label='SVM points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# # (60-40) SPLIT

# %%
model4 = SVR(kernel='rbf')
model4.fit(X_train2, y_train2)
# Out:
# SVR()

# %%
y_pred4=model4.predict(X_test4)
svm4 = pd.DataFrame({'Predicted':y_pred4,'Actual':y_test4})
svm4
# Out:
#      Predicted  Actual
# 532  11.450085       8
# 375  11.898579      15
# 306  11.827092      16
# 625  12.032568      10
# 480  11.471033      10
# ..         ...     ...
# 140  11.362452      10
# 587  11.238234       8
# 225  10.801710      12
# 536  11.125966      14
# 605  10.301371       0
#
# [260 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS FOR (60-40) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_test4,y_pred4))
# Out:
# MAE: 2.1962383892166573
# RMSE: 3.09582186666757
# R2 score: 0.1586452834458154

# %%
plt.scatter(X_test4['absences'], y_test4, label='Test Data')
plt.scatter(X_test4['absences'], y_pred4, color='red', linewidth=1, label='SVM points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # (80-20) SPLIT

# %%
# Create Decision Tree classifer object
reg1 = DecisionTreeRegressor()

# Train Decision Tree Classifer
reg1 = reg1.fit(X_train1,y_train1)

# %%
#Predict the response for test dataset
y_pred1 = reg1.predict(X_test1)
print("Accuracy:",metrics.accuracy_score(y_test1, y_pred1))
# Out:
# Accuracy: 0.19230769230769232

# %% [markdown]
# EVALUATION METRICS (80-20) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_test1,y_pred1))
# Out:
# MAE: 2.730769230769231
# RMSE: 3.600213668872788
# R2 score: -0.8245652029053105

# %% [markdown]
# #(75-25) SPLIT

# %%
# Create Decision Tree classifer object
reg2 = DecisionTreeRegressor()

# Train Decision Tree Classifer
reg2 = reg2.fit(X_train2,y_train2)

# %%
#Predict the response for test dataset
y_pred2 = reg2.predict(X_test2)
print("Accuracy:",metrics.accuracy_score(y_test2, y_pred2))
# Out:
# Accuracy: 0.1411042944785276

# %% [markdown]
#  EVALUATION METRICS (75-25) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_test2,y_pred2))
# Out:
# MAE: 2.607361963190184
# RMSE: 3.6427926993320314
# R2 score: -0.47020140944914735

# %% [markdown]
# # (70-30) SPLIT

# %%
# Create Decision Tree classifer object
reg3 = DecisionTreeRegressor()

# Train Decision Tree Classifer
reg3 = reg3.fit(X_train3,y_train3)

# %%
#Predict the response for test dataset
y_pred3 = reg3.predict(X_test3)
print("Accuracy:",metrics.accuracy_score(y_test3, y_pred3))
# Out:
# Accuracy: 0.1076923076923077

# %% [markdown]
#  EVALUATION METRICS (70-30) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_test3,y_pred3))
# Out:
# MAE: 2.764102564102564
# RMSE: 3.7601145645394287
# R2 score: -0.4398756213575592

# %% [markdown]
# # (60-40) SPLIT

# %%
# Create Decision Tree classifer object
reg4 = DecisionTreeRegressor()

# Train Decision Tree Classifer
reg4 = reg4.fit(X_train4,y_train4)

# %%
#Predict the response for test dataset
y_pred4 = reg4.predict(X_test4)
print("Accuracy:",metrics.accuracy_score(y_test4, y_pred4))
# Out:
# Accuracy: 0.11923076923076924

# %% [markdown]
# EVALUATION METRICS (60-40) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_test4,y_pred4))
# Out:
# MAE: 2.876923076923077
# RMSE: 3.9807227793648035
# R2 score: -0.39107669492020647

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # (80-20) SPLIT

# %%
rf1 = RandomForestRegressor()
rf1.fit(X_train1, y_train1)
# Out:
# RandomForestRegressor()

# %%
y_pred1=rf1.predict(X_test1)

# %% [markdown]
#  EVALUATION METRICS (80-20) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_test1,y_pred1))
# Out:
# MAE: 1.731
# RMSE: 2.389116186761572
# R2 score: 0.19651573432398217

# %% [markdown]
# # (75-25) SPLIT

# %%
rf2 = RandomForestRegressor()
rf2.fit(X_train2, y_train2)
# Out:
# RandomForestRegressor()

# %%
y_pred2=rf2.predict(X_test2)

# %% [markdown]
#  EVALUATION METRICS (75-25) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_test2,y_pred2))
# Out:
# MAE: 1.921288343558282
# RMSE: 2.639755170837476
# R2 score: 0.2279681485342563

# %% [markdown]
# #  (70-30) SPLIT

# %%
rf3 = RandomForestRegressor()
rf3.fit(X_train3, y_train3)
# Out:
# RandomForestRegressor()

# %%
y_pred3=rf3.predict(X_test3)

# %% [markdown]
#  EVALUATION METRICS (70-30 ) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_test3,y_pred3))
# Out:
# MAE: 2.0012820512820513
# RMSE: 2.7032080656423485
# R2 score: 0.25581352443649297

# %% [markdown]
# #  (60-40) SPLIT

# %%
rf4 = RandomForestRegressor()
rf4.fit(X_train4, y_train4)
# Out:
# RandomForestRegressor()

# %%
y_pred4=rf4.predict(X_test4)

# %% [markdown]
# EVALUATION METRICS (60-40) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_test4,y_pred4))
# Out:
# MAE: 2.081461538461539
# RMSE: 2.9661770267207843
# R2 score: 0.22763721363909672

# %% [markdown]
# # XGboost

# %%
import xgboost as xgb

# %% [markdown]
# # (80-20) SPLIT

# %%
model1 = xgb.XGBRegressor()
model2 = xgb.XGBRegressor(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(X_train1, y_train1)
train_model2 = model2.fit(X_train1, y_train1)

# %%
pred1 = train_model1.predict(X_test1)
pred2 = train_model2.predict(X_test1)

# %% [markdown]
# EVALUATION METRICS (80-20) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test1,pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test1,pred1)))
print("R2 score:",metrics.r2_score(y_test1,pred1))
print("MAE:",metrics.mean_absolute_error(y_test1,pred2)) # Use pred2 instead of y_pred2
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test1, pred2))) # Use pred2 instead of y_pred2
print("R2 score:",metrics.r2_score(y_test1,pred2)) # Use pred2 instead of y_pred2
# Out:
# MAE: 2.012354185948005
# RMSE: 2.7662932530022037
# R2 score: -0.07720732688903809
# MAE: 1.8546384371243991
# RMSE: 2.473397981943008
# R2 score: 0.1388261914253235

# %% [markdown]
# # (75-25) SPLIT

# %%
model1 = xgb.XGBRegressor()
model2 = xgb.XGBRegressor(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(X_train2, y_train2)
train_model2 = model2.fit(X_train2, y_train2)

# %%
pred1 = train_model1.predict(X_test2)
pred2 = train_model2.predict(X_test2)

# %% [markdown]
# EVALUATION METRICS (75-25) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test2,pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test2, pred1)))
print("R2 score:",metrics.r2_score(y_test2,pred1))
print("MAE:",metrics.mean_absolute_error(y_test2,pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test2, pred2)))
print("R2 score:",metrics.r2_score(y_test2,pred2))
# Out:
# MAE: 2.103302094102637
# RMSE: 2.8811606702432098
# R2 score: 0.08030706644058228
# MAE: 1.8571471114831468
# RMSE: 2.6319665055690633
# R2 score: 0.23251718282699585

# %% [markdown]
# # (70-30) SPLIT

# %%
model1 = xgb.XGBRegressor()
model2 = xgb.XGBRegressor(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(X_train3, y_train3)
train_model2 = model2.fit(X_train3, y_train3)

# %%
pred1 = train_model1.predict(X_test3)
pred2 = train_model2.predict(X_test3)

# %% [markdown]
# EVALUATION METRICS (70-30) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test3,pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test3, pred1)))
print("R2 score:",metrics.r2_score(y_test3,pred1))
print("MAE:",metrics.mean_absolute_error(y_test3,pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test3, pred2)))
print("R2 score:",metrics.r2_score(y_test3,pred2))
# Out:
# MAE: 2.1490776104804796
# RMSE: 3.0424688248904874
# R2 score: 0.05729645490646362
# MAE: 2.0082247868562355
# RMSE: 2.811553126445059
# R2 score: 0.1949637532234192

# %% [markdown]
# # (60-40) SPLIT

# %%
model1 = xgb.XGBRegressor()
model2 = xgb.XGBRegressor(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(X_train4, y_train4)
train_model2 = model2.fit(X_train4, y_train4)

# %%
pred1 = train_model1.predict(X_test4)
pred2 = train_model2.predict(X_test4)

# %%
print("MAE:",metrics.mean_absolute_error(y_test4,pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test4, pred1)))
print("R2 score:",metrics.r2_score(y_test4,pred1))
print("MAE:",metrics.mean_absolute_error(y_test4,pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test4, pred2)))
print("R2 score:",metrics.r2_score(y_test4,pred2))
# Out:
# MAE: 2.2181860718589563
# RMSE: 3.1825794558022786
# R2 score: 0.11082810163497925
# MAE: 2.137529562986814
# RMSE: 3.0890817926475016
# R2 score: 0.16230475902557373

# %% [markdown]
# # ADAboost

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor

# Replace 'base_estimator' with 'estimator'
base_estimator = DecisionTreeRegressor(max_depth=3, random_state=0)

# %% [markdown]
# # (80-20) SPLIT

# %%
adaboost = AdaBoostRegressor(estimator=base_estimator, # Changed argument name here
                              n_estimators=3,random_state=0)
adaboost.fit(X_train1, y_train1)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3, random_state=0),
#                   n_estimators=3, random_state=0)

# %%
y_pred1 = adaboost.predict(X_test1)

# %% [markdown]
# EVALUATION METRICS (80-20) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_test1,y_pred1))
# Out:
# MAE: 1.8705079462462006
# RMSE: 2.566728487513412
# R2 score: 0.07260938500734804

# %% [markdown]
# # (75-25) SPLIT

# %%
adaboost = AdaBoostRegressor(estimator=base_estimator, # Changed argument name here
                              n_estimators=3,random_state=0)
adaboost.fit(X_train2, y_train2)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3, random_state=0),
#                   n_estimators=3, random_state=0)

# %%
y_pred2 = adaboost.predict(X_test2)

# %% [markdown]
# EVALUATION METRICS (75-25) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_test2,y_pred2))
# Out:
# MAE: 2.022806519799029
# RMSE: 2.7236965657772267
# R2 score: 0.1780879149322634

# %% [markdown]
# # (70-30) SPLIT

# %%
adaboost = AdaBoostRegressor(estimator=base_estimator, # Changed argument name here
                              n_estimators=3,random_state=0)
adaboost.fit(X_train3, y_train3)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3, random_state=0),
#                   n_estimators=3, random_state=0)

# %%
y_pred3 = adaboost.predict(X_test3)

# %% [markdown]
# EVALUATION  METRICS (70-30) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_test3,y_pred3))
# Out:
# MAE: 2.007857846738763
# RMSE: 2.7681930668079215
# R2 score: 0.21960302532549203

# %% [markdown]
# # (60-40) SPLIT

# %%
adaboost = AdaBoostRegressor(estimator=base_estimator, # Changed argument name here
                              n_estimators=3,random_state=0)
adaboost.fit(X_train4, y_train4)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3, random_state=0),
#                   n_estimators=3, random_state=0)

# %%
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test4,y_pred4)))
print("R2 score:",metrics.r2_score(y_test4,y_pred4))
# Out:
# RMSE: 2.9661770267207843
# R2 score: 0.22763721363909672

# %% [markdown]
# EVALUATION METRICS (60-40) SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_test4,y_pred4))
# Out:
# MAE: 2.081461538461539
# RMSE: 2.9661770267207843
# R2 score: 0.22763721363909672

# %% [markdown]
# # ANN

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 80-20 SPLIT

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([

                            tf.keras.layers.Dense(30),

                            tf.keras.layers.Dense(25),

                            tf.keras.layers.Dense(20),

                            tf.keras.layers.Dense(15),

                            tf.keras.layers.Dense(10),

                            tf.keras.layers.Dense(5),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam
# Set the learning rate when creating the Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss= tf.keras.losses.mae,
              optimizer= optimizer,  # Use the optimizer with the specified learning rate
              metrics= ["mae"])

# STEP3: Fit the model
# Remove learning_rate from fit() arguments
history= model.fit(X_train1, y_train1, epochs= 150, verbose=1)
# Out:
# Epoch 1/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.0814 - mae: 10.0814
# Epoch 2/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4108 - mae: 3.4108
# Epoch 3/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7789 - mae: 2.7789
# Epoch 4/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5488 - mae: 2.5488
# Epoch 5/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3033 - mae: 2.3033
# Epoch 6/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1939 - mae: 2.1939
# Epoch 7/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1513 - mae: 2.1513
# Epoch 8/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0972 - mae: 2.0972
# Epoch 9/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0555 - mae: 2.0555
# Epoch 10/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0108 - mae: 2.0108
# Epoch 11/150
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9776 - mae: 1.9776
# Epoch 12/150
# ...

# %%
model.evaluate(X_test1, y_test1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8787 - mae: 1.8787
# [1.7550042867660522, 1.7550042867660522]

# %%
model.summary();
# Out:
# Model: "sequential_83"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_515 (Dense)                    │ (None, 30)                  │           1,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_516 (Dense)                    │ (None, 25)                  │             775 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_517 (Dense)                    │ (None, 20)                  │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_518 (Dense)                    │ (None, 15)                  │             315 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# # 75-25 SPLIT

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([

                             tf.keras.layers.Dense(30),
                            tf.keras.layers.Dense(40),
                            tf.keras.layers.Dense(20),
                            tf.keras.layers.Dense(10),
                            tf.keras.layers.Dense(5),
                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam
# Set the learning rate when creating the Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss= tf.keras.losses.mae,
              optimizer= optimizer,  # Use the optimizer with the specified learning rate
              metrics= ["mae"])

# STEP3: Fit the model
# Remove learning_rate from fit() arguments
history= model.fit(X_train2, y_train2, epochs= 120, verbose=1)
# Out:
# Epoch 1/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 7.1166 - mae: 7.1166
# Epoch 2/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2276 - mae: 3.2276
# Epoch 3/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0384 - mae: 3.0384
# Epoch 4/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6385 - mae: 2.6385
# Epoch 5/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5153 - mae: 2.5153
# Epoch 6/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4603 - mae: 2.4603
# Epoch 7/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3560 - mae: 2.3560
# Epoch 8/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2544 - mae: 2.2544
# Epoch 9/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1601 - mae: 2.1601
# Epoch 10/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1044 - mae: 2.1044
# Epoch 11/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0569 - mae: 2.0569
# Epoch 12/120
# ...

# %%
model.evaluate(X_test2, y_test2)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0771 - mae: 2.0771
# [2.030736207962036, 2.030736207962036]

# %%
model.summary();
# Out:
# Model: "sequential_84"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_522 (Dense)                    │ (None, 30)                  │           1,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_523 (Dense)                    │ (None, 40)                  │           1,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_524 (Dense)                    │ (None, 20)                  │             820 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_525 (Dense)                    │ (None, 10)                  │             210 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# # 70-30 SPLIT

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([
                          tf.keras.layers.Dense(60),

                            tf.keras.layers.Dense(30),

                            tf.keras.layers.Dense(20),

                            tf.keras.layers.Dense(15),

                            tf.keras.layers.Dense(10),

                            tf.keras.layers.Dense(5),

                            tf.keras.layers.Dense(3),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam
# Set the learning rate when creating the Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.005)

model.compile(loss= tf.keras.losses.mae,
              optimizer= optimizer,  # Use the optimizer with the specified learning rate
              metrics= ["mae"])

# STEP3: Fit the model
# Remove learning_rate from fit() arguments
history= model.fit(X_train3, y_train3, epochs= 120, verbose=1)
# Out:
# Epoch 1/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 7.8233 - mae: 7.8233
# Epoch 2/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5769 - mae: 2.5769
# Epoch 3/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2796 - mae: 2.2796
# Epoch 4/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1239 - mae: 2.1239
# Epoch 5/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1019 - mae: 2.1019
# Epoch 6/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4308 - mae: 2.4308
# Epoch 7/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0751 - mae: 2.0751
# Epoch 8/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0617 - mae: 2.0617
# Epoch 9/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1127 - mae: 2.1127
# Epoch 10/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1664 - mae: 2.1664
# Epoch 11/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1515 - mae: 2.1515
# Epoch 12/120
# ...

# %%
model.evaluate(X_test3, y_test3)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0097 - mae: 2.0097
# [2.0253071784973145, 2.0253071784973145]

# %%
model.summary();
# Out:
# Model: "sequential_85"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_528 (Dense)                    │ (None, 60)                  │           2,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_529 (Dense)                    │ (None, 30)                  │           1,830 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_530 (Dense)                    │ (None, 20)                  │             620 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_531 (Dense)                    │ (None, 15)                  │             315 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# # 60-40 SPLIT

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([

                         tf.keras.layers.Dense(30),

                            tf.keras.layers.Dense(25),

                            tf.keras.layers.Dense(20),

                            tf.keras.layers.Dense(15),

                            tf.keras.layers.Dense(10),

                            tf.keras.layers.Dense(5),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam
# Set the learning rate when creating the Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.005)

model.compile(loss= tf.keras.losses.mae,
              optimizer= optimizer,  # Use the optimizer with the specified learning rate
              metrics= ["mae"])

# STEP3: Fit the model
# Remove learning_rate from fit() arguments
history= model.fit(X_train4, y_train4, epochs= 120, verbose=1)
# Out:
# Epoch 1/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 7.5821 - mae: 7.5821
# Epoch 2/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6007 - mae: 2.6007
# Epoch 3/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3086 - mae: 2.3086
# Epoch 4/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1955 - mae: 2.1955
# Epoch 5/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1223 - mae: 2.1223
# Epoch 6/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3321 - mae: 2.3321
# Epoch 7/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0536 - mae: 2.0536
# Epoch 8/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4023 - mae: 2.4023
# Epoch 9/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0946 - mae: 2.0946
# Epoch 10/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0850 - mae: 2.0850
# Epoch 11/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0146 - mae: 2.0146
# Epoch 12/120
# ...

# %%
model.evaluate(X_test4, y_test4)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1699 - mae: 2.1699
# [2.263777494430542, 2.263777494430542]

# %%
model.summary();
# Out:
# Model: "sequential_86"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_536 (Dense)                    │ (None, 30)                  │           1,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_537 (Dense)                    │ (None, 25)                  │             775 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_538 (Dense)                    │ (None, 20)                  │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_539 (Dense)                    │ (None, 15)                  │             315 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# # MULTICOLLINEARITY

# %%
# Import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd # Make sure pandas is imported

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i).round(1) for i in range(X.shape[1])]

    return(vif)

calc_vif(X)
# Out:
#             variables   VIF
# 0              school   2.3
# 1                 sex   2.3
# 2                 age  69.7
# 3             address   1.9
# 4             famsize   3.8
# 5             Pstatus   1.3
# 6                Medu  15.9
# 7                Fedu  11.3
# 8          traveltime   6.8
# 9           studytime   7.9
# 10           failures   1.5
# 11          schoolsup   1.2
# 12             famsup   2.9
# 13               paid   1.2
# 14         activities   2.2
# 15            nursery   5.4
# 16             higher  11.3
# 17           internet   5.3
# 18           romantic   1.8
# 19             famrel  19.7
# 20           freetime  12.5
# 21              goout  12.1
# 22               Dalc   6.7
# 23               Walc   8.8
# 24             health   7.9
# 25           absences   2.0
# 26        Mjob_health   1.9
# 27         Mjob_other   3.3
# 28      Mjob_services   2.7
# 29       Mjob_teacher   2.6
# 30        Fjob_health   1.8
# 31         Fjob_other  10.4
# ...

# %%
calc_vif(X.drop('age',axis=1))
# Out:
#             variables   VIF
# 0              school   2.1
# 1                 sex   2.3
# 2             address   1.9
# 3             famsize   3.7
# 4             Pstatus   1.3
# 5                Medu  15.7
# 6                Fedu  11.2
# 7          traveltime   6.5
# 8           studytime   7.2
# 9            failures   1.4
# 10          schoolsup   1.2
# 11             famsup   2.9
# 12               paid   1.2
# 13         activities   2.2
# 14            nursery   5.2
# 15             higher  11.0
# 16           internet   5.3
# 17           romantic   1.7
# 18             famrel  17.5
# 19           freetime  12.2
# 20              goout  12.0
# 21               Dalc   6.6
# 22               Walc   8.6
# 23             health   7.6
# 24           absences   1.9
# 25        Mjob_health   1.9
# 26         Mjob_other   3.3
# 27      Mjob_services   2.7
# 28       Mjob_teacher   2.5
# 29        Fjob_health   1.8
# 30         Fjob_other   9.8
# 31      Fjob_services   5.3
# ...

# %%
calc_vif(X.drop(['age','famrel'],axis=1))
# Out:
#             variables   VIF
# 0              school   2.1
# 1                 sex   2.3
# 2             address   1.9
# 3             famsize   3.7
# 4             Pstatus   1.3
# 5                Medu  15.7
# 6                Fedu  11.2
# 7          traveltime   6.5
# 8           studytime   7.2
# 9            failures   1.4
# 10          schoolsup   1.2
# 11             famsup   2.9
# 12               paid   1.2
# 13         activities   2.2
# 14            nursery   5.1
# 15             higher  10.8
# 16           internet   5.2
# 17           romantic   1.7
# 18           freetime  11.8
# 19              goout  11.8
# 20               Dalc   6.6
# 21               Walc   8.5
# 22             health   7.3
# 23           absences   1.9
# 24        Mjob_health   1.9
# 25         Mjob_other   3.3
# 26      Mjob_services   2.7
# 27       Mjob_teacher   2.5
# 28        Fjob_health   1.8
# 29         Fjob_other   9.5
# 30      Fjob_services   5.1
# 31       Fjob_teacher   2.2
# ...

# %%
calc_vif(X.drop(['age','famrel','Medu'],axis=1))
# Out:
#             variables   VIF
# 0              school   2.1
# 1                 sex   2.3
# 2             address   1.9
# 3             famsize   3.7
# 4             Pstatus   1.3
# 5                Fedu   8.1
# 6          traveltime   6.4
# 7           studytime   7.1
# 8            failures   1.4
# 9           schoolsup   1.2
# 10             famsup   2.9
# 11               paid   1.2
# 12         activities   2.2
# 13            nursery   5.0
# 14             higher  10.8
# 15           internet   5.2
# 16           romantic   1.7
# 17           freetime  11.8
# 18              goout  11.7
# 19               Dalc   6.6
# 20               Walc   8.5
# 21             health   7.3
# 22           absences   1.9
# 23        Mjob_health   1.7
# 24         Mjob_other   3.2
# 25      Mjob_services   2.4
# 26       Mjob_teacher   2.1
# 27        Fjob_health   1.8
# 28         Fjob_other   9.5
# 29      Fjob_services   5.1
# 30       Fjob_teacher   2.2
# 31        reason_home   1.7
# ...

# %%
calc_vif(X.drop(['age','famrel','Medu','goout'],axis=1))
# Out:
#             variables   VIF
# 0              school   2.1
# 1                 sex   2.3
# 2             address   1.9
# 3             famsize   3.7
# 4             Pstatus   1.3
# 5                Fedu   8.1
# 6          traveltime   6.4
# 7           studytime   7.1
# 8            failures   1.4
# 9           schoolsup   1.2
# 10             famsup   2.8
# 11               paid   1.2
# 12         activities   2.2
# 13            nursery   5.0
# 14             higher  10.8
# 15           internet   5.1
# 16           romantic   1.7
# 17           freetime  10.2
# 18               Dalc   6.6
# 19               Walc   7.5
# 20             health   7.2
# 21           absences   1.9
# 22        Mjob_health   1.7
# 23         Mjob_other   3.2
# 24      Mjob_services   2.4
# 25       Mjob_teacher   2.0
# 26        Fjob_health   1.8
# 27         Fjob_other   9.4
# 28      Fjob_services   5.1
# 29       Fjob_teacher   2.2
# 30        reason_home   1.7
# 31       reason_other   1.4
# ...

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher'],axis=1))
# Out:
#             variables   VIF
# 0              school   2.1
# 1                 sex   2.3
# 2             address   1.9
# 3             famsize   3.7
# 4             Pstatus   1.3
# 5                Fedu   7.9
# 6          traveltime   6.3
# 7           studytime   6.8
# 8            failures   1.4
# 9           schoolsup   1.2
# 10             famsup   2.8
# 11               paid   1.2
# 12         activities   2.2
# 13            nursery   5.0
# 14           internet   5.1
# 15           romantic   1.7
# 16           freetime  10.2
# 17               Dalc   6.6
# 18               Walc   7.5
# 19             health   7.1
# 20           absences   1.9
# 21        Mjob_health   1.6
# 22         Mjob_other   3.1
# 23      Mjob_services   2.4
# 24       Mjob_teacher   2.0
# 25        Fjob_health   1.8
# 26         Fjob_other   9.2
# 27      Fjob_services   4.9
# 28       Fjob_teacher   2.2
# 29        reason_home   1.7
# 30       reason_other   1.4
# 31  reason_reputation   1.8
# ...

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime'],axis=1))
# Out:
#             variables  VIF
# 0              school  2.1
# 1                 sex  2.2
# 2             address  1.9
# 3             famsize  3.6
# 4             Pstatus  1.3
# 5                Fedu  7.8
# 6          traveltime  6.3
# 7           studytime  6.7
# 8            failures  1.4
# 9           schoolsup  1.2
# 10             famsup  2.8
# 11               paid  1.1
# 12         activities  2.1
# 13            nursery  4.9
# 14           internet  5.0
# 15           romantic  1.7
# 16               Dalc  6.5
# 17               Walc  7.5
# 18             health  7.0
# 19           absences  1.9
# 20        Mjob_health  1.6
# 21         Mjob_other  3.1
# 22      Mjob_services  2.4
# 23       Mjob_teacher  2.0
# 24        Fjob_health  1.8
# 25         Fjob_other  9.1
# 26      Fjob_services  4.9
# 27       Fjob_teacher  2.2
# 28        reason_home  1.7
# 29       reason_other  1.4
# 30  reason_reputation  1.8
# 31    guardian_mother  4.1
# 32     guardian_other  1.5

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other'],axis=1))
# Out:
#             variables  VIF
# 0              school  2.1
# 1                 sex  2.2
# 2             address  1.9
# 3             famsize  3.6
# 4             Pstatus  1.3
# 5                Fedu  7.6
# 6          traveltime  5.9
# 7           studytime  6.6
# 8            failures  1.3
# 9           schoolsup  1.2
# 10             famsup  2.8
# 11               paid  1.1
# 12         activities  2.1
# 13            nursery  4.9
# 14           internet  4.9
# 15           romantic  1.7
# 16               Dalc  6.5
# 17               Walc  7.4
# 18             health  6.7
# 19           absences  1.9
# 20        Mjob_health  1.6
# 21         Mjob_other  3.0
# 22      Mjob_services  2.4
# 23       Mjob_teacher  2.0
# 24        Fjob_health  1.3
# 25      Fjob_services  1.6
# 26       Fjob_teacher  1.4
# 27        reason_home  1.6
# 28       reason_other  1.4
# 29  reason_reputation  1.7
# 30    guardian_mother  4.0
# 31     guardian_other  1.5

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other','Fedu'],axis=1))
# Out:
#             variables  VIF
# 0              school  2.1
# 1                 sex  2.2
# 2             address  1.9
# 3             famsize  3.5
# 4             Pstatus  1.3
# 5          traveltime  5.9
# 6           studytime  6.5
# 7            failures  1.3
# 8           schoolsup  1.2
# 9              famsup  2.8
# 10               paid  1.1
# 11         activities  2.1
# 12            nursery  4.8
# 13           internet  4.8
# 14           romantic  1.7
# 15               Dalc  6.5
# 16               Walc  7.3
# 17             health  6.6
# 18           absences  1.9
# 19        Mjob_health  1.6
# 20         Mjob_other  3.0
# 21      Mjob_services  2.4
# 22       Mjob_teacher  1.9
# 23        Fjob_health  1.2
# 24      Fjob_services  1.6
# 25       Fjob_teacher  1.2
# 26        reason_home  1.6
# 27       reason_other  1.4
# 28  reason_reputation  1.7
# 29    guardian_mother  4.0
# 30     guardian_other  1.5

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other','Fedu','Walc'],axis=1))
# Out:
#             variables  VIF
# 0              school  2.1
# 1                 sex  2.2
# 2             address  1.9
# 3             famsize  3.5
# 4             Pstatus  1.3
# 5          traveltime  5.8
# 6           studytime  6.5
# 7            failures  1.3
# 8           schoolsup  1.2
# 9              famsup  2.8
# 10               paid  1.1
# 11         activities  2.1
# 12            nursery  4.8
# 13           internet  4.8
# 14           romantic  1.7
# 15               Dalc  4.3
# 16             health  6.4
# 17           absences  1.9
# 18        Mjob_health  1.6
# 19         Mjob_other  3.0
# 20      Mjob_services  2.4
# 21       Mjob_teacher  1.9
# 22        Fjob_health  1.2
# 23      Fjob_services  1.6
# 24       Fjob_teacher  1.2
# 25        reason_home  1.6
# 26       reason_other  1.4
# 27  reason_reputation  1.7
# 28    guardian_mother  3.9
# 29     guardian_other  1.5

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other','Fedu','Walc','health'],axis=1))
# Out:
#             variables  VIF
# 0              school  2.1
# 1                 sex  2.1
# 2             address  1.9
# 3             famsize  3.5
# 4             Pstatus  1.3
# 5          traveltime  5.8
# 6           studytime  6.3
# 7            failures  1.3
# 8           schoolsup  1.2
# 9              famsup  2.8
# 10               paid  1.1
# 11         activities  2.1
# 12            nursery  4.7
# 13           internet  4.7
# 14           romantic  1.7
# 15               Dalc  4.2
# 16           absences  1.9
# 17        Mjob_health  1.5
# 18         Mjob_other  2.9
# 19      Mjob_services  2.3
# 20       Mjob_teacher  1.9
# 21        Fjob_health  1.2
# 22      Fjob_services  1.6
# 23       Fjob_teacher  1.2
# 24        reason_home  1.6
# 25       reason_other  1.4
# 26  reason_reputation  1.7
# 27    guardian_mother  3.9
# 28     guardian_other  1.5

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other','Fedu','Walc','health','studytime'],axis=1))
# Out:
#             variables  VIF
# 0              school  2.1
# 1                 sex  2.1
# 2             address  1.9
# 3             famsize  3.4
# 4             Pstatus  1.3
# 5          traveltime  5.5
# 6            failures  1.3
# 7           schoolsup  1.2
# 8              famsup  2.7
# 9                paid  1.1
# 10         activities  2.1
# 11            nursery  4.6
# 12           internet  4.7
# 13           romantic  1.7
# 14               Dalc  4.2
# 15           absences  1.9
# 16        Mjob_health  1.5
# 17         Mjob_other  2.8
# 18      Mjob_services  2.3
# 19       Mjob_teacher  1.9
# 20        Fjob_health  1.2
# 21      Fjob_services  1.6
# 22       Fjob_teacher  1.2
# 23        reason_home  1.6
# 24       reason_other  1.4
# 25  reason_reputation  1.7
# 26    guardian_mother  3.8
# 27     guardian_other  1.5

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other','Fedu','Walc','health','studytime','traveltime'],axis=1))
# Out:
#             variables  VIF
# 0              school  2.0
# 1                 sex  2.1
# 2             address  1.7
# 3             famsize  3.3
# 4             Pstatus  1.3
# 5            failures  1.3
# 6           schoolsup  1.2
# 7              famsup  2.6
# 8                paid  1.1
# 9          activities  2.1
# 10            nursery  4.4
# 11           internet  4.7
# 12           romantic  1.7
# 13               Dalc  4.1
# 14           absences  1.9
# 15        Mjob_health  1.5
# 16         Mjob_other  2.8
# 17      Mjob_services  2.3
# 18       Mjob_teacher  1.9
# 19        Fjob_health  1.2
# 20      Fjob_services  1.6
# 21       Fjob_teacher  1.2
# 22        reason_home  1.6
# 23       reason_other  1.4
# 24  reason_reputation  1.7
# 25    guardian_mother  3.7
# 26     guardian_other  1.5

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other','Fedu','Walc','health','studytime','traveltime','nursery'],axis=1))
# Out:
#             variables  VIF
# 0              school  1.9
# 1                 sex  2.1
# 2             address  1.7
# 3             famsize  3.3
# 4             Pstatus  1.3
# 5            failures  1.3
# 6           schoolsup  1.2
# 7              famsup  2.6
# 8                paid  1.1
# 9          activities  2.1
# 10           internet  4.6
# 11           romantic  1.7
# 12               Dalc  4.1
# 13           absences  1.9
# 14        Mjob_health  1.5
# 15         Mjob_other  2.8
# 16      Mjob_services  2.3
# 17       Mjob_teacher  1.9
# 18        Fjob_health  1.2
# 19      Fjob_services  1.6
# 20       Fjob_teacher  1.2
# 21        reason_home  1.6
# 22       reason_other  1.4
# 23  reason_reputation  1.6
# 24    guardian_mother  3.6
# 25     guardian_other  1.5

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other','Fedu','Walc','health','studytime','traveltime','nursery','internet'],axis=1))
# Out:
#             variables  VIF
# 0              school  1.9
# 1                 sex  2.1
# 2             address  1.7
# 3             famsize  3.3
# 4             Pstatus  1.3
# 5            failures  1.3
# 6           schoolsup  1.2
# 7              famsup  2.6
# 8                paid  1.1
# 9          activities  2.1
# 10           romantic  1.7
# 11               Dalc  4.0
# 12           absences  1.9
# 13        Mjob_health  1.4
# 14         Mjob_other  2.6
# 15      Mjob_services  2.1
# 16       Mjob_teacher  1.7
# 17        Fjob_health  1.2
# 18      Fjob_services  1.6
# 19       Fjob_teacher  1.2
# 20        reason_home  1.6
# 21       reason_other  1.3
# 22  reason_reputation  1.6
# 23    guardian_mother  3.5
# 24     guardian_other  1.4

# %%
calc_vif(X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other','Fedu','Walc','health','studytime','traveltime','nursery','internet','Dalc'],axis=1))
# Out:
#             variables  VIF
# 0              school  1.9
# 1                 sex  1.8
# 2             address  1.7
# 3             famsize  3.3
# 4             Pstatus  1.3
# 5            failures  1.3
# 6           schoolsup  1.2
# 7              famsup  2.5
# 8                paid  1.1
# 9          activities  2.1
# 10           romantic  1.7
# 11           absences  1.8
# 12        Mjob_health  1.4
# 13         Mjob_other  2.6
# 14      Mjob_services  2.1
# 15       Mjob_teacher  1.7
# 16        Fjob_health  1.2
# 17      Fjob_services  1.5
# 18       Fjob_teacher  1.2
# 19        reason_home  1.6
# 20       reason_other  1.3
# 21  reason_reputation  1.6
# 22    guardian_mother  3.5
# 23     guardian_other  1.4

# %%
x_nomulti = X.drop(['age','famrel','Medu','goout','higher','freetime','Fjob_other','Fedu','Walc','health','studytime','traveltime','nursery','internet','Dalc'], axis=1)

# %%
x_nomulti_train1,x_nomulti_test1,y_nomulti_train1,y_nomulti_test1=train_test_split(x_nomulti,y,test_size=0.20,random_state=0)
x_nomulti_train2,x_nomulti_test2,y_nomulti_train2,y_nomulti_test2=train_test_split(x_nomulti,y,test_size=0.25,random_state=0)
x_nomulti_train3,x_nomulti_test3,y_nomulti_train3,y_nomulti_test3=train_test_split(x_nomulti,y,test_size=0.30,random_state=0)
x_nomulti_train4,x_nomulti_test4,y_nomulti_train4,y_nomulti_test4=train_test_split(x_nomulti,y,test_size=0.40,random_state=0)

# %% [markdown]
# # LINEAR REGRESSION

# %% [markdown]
# # 80-20 SPLIT

# %%
linreg = LinearRegression()
linreg.fit(x_nomulti_train1, y_nomulti_train1)
y_pred1 = linreg.predict(x_nomulti_test1)

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test1,y_pred1))
# Out:
# MAE: 1.7116744381719178
# RMSE: 2.41838021520658
# R2 score: 0.1767115977242757

# %% [markdown]
# # 75-25 SPLIT

# %%
linreg = LinearRegression()
linreg.fit(x_nomulti_train2, y_nomulti_train2)
y_pred2 = linreg.predict(x_nomulti_test2)

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test2,y_pred2))
# Out:
# MAE: 1.8542972439451266
# RMSE: 2.678257617393062
# R2 score: 0.20528279124107185

# %% [markdown]
# # 70-30 SPLIT

# %%
linreg = LinearRegression()
linreg.fit(x_nomulti_train3, y_nomulti_train3)
y_pred3 = linreg.predict(x_nomulti_test3)

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_nomulti_test3,y_pred3))
# Out:
# MAE: 1.9051425074127049
# RMSE: 2.7157633391228746
# R2 score: 0.248884599439818

# %% [markdown]
# # 60-40 SPLIT

# %%
linreg = LinearRegression()
linreg.fit(x_nomulti_train4, y_nomulti_train4)
y_pred4 = linreg.predict(x_nomulti_test4)

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_nomulti_test4,y_pred4))
# Out:
# MAE: 2.1644467367995315
# RMSE: 3.086703795792932
# R2 score: 0.16359404009310485

# %% [markdown]
# # KNN

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# # 80-20 SPLIT

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(x_nomulti_train1, y_nomulti_train1)
y_pred1 = model.predict(x_nomulti_test1)
knn = pd.DataFrame({'Predicted':y_pred1,'Actual':y_nomulti_test1})
knn
# Out:
#      Predicted  Actual
# 532       12.6       8
# 375       13.2      15
# 306       12.6      16
# 625       13.0      10
# 480       11.8      10
# ..         ...     ...
# 403       11.2      15
# 266       15.2      14
# 641       13.4      15
# 558        7.6      10
# 242       10.4      11
#
# [130 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS 80-20 SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test1,y_pred1))
# Out:
# MAE: 1.9553846153846153
# RMSE: 2.65683443796734
# R2 score: 0.006353701605917306

# %%
plt.scatter(x_nomulti_test1['absences'], y_nomulti_test1, label='Test Data')
plt.scatter(x_nomulti_test1['absences'], y_pred1, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# # 75-25 SPLIT

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(x_nomulti_train2, y_nomulti_train2)
y_pred2 = model.predict(x_nomulti_test2)

# %%
knn = pd.DataFrame({'Predicted':y_pred2,'Actual':y_nomulti_test2})
knn
# Out:
#      Predicted  Actual
# 532       13.2       8
# 375       13.0      15
# 306       12.6      16
# 625       12.0      10
# 480       12.2      10
# ..         ...     ...
# 588       14.2       9
# 332       14.4      18
# 202       13.2      14
# 316       13.8      16
# 90        11.8      11
#
# [163 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS 75-25 SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test2,y_pred2))
# Out:
# MAE: 2.1693251533742335
# RMSE: 2.9361299180563383
# R2 score: 0.0448788624327594

# %%
plt.scatter(x_nomulti_test2['absences'], y_nomulti_test2, label='Test Data')
plt.scatter(x_nomulti_test2['absences'], y_pred2, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# # 70-30 SPLIT

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(x_nomulti_train3, y_nomulti_train3)
y_pred3 = model.predict(x_nomulti_test3)

# %%
knn = pd.DataFrame({'Predicted':y_pred3,'Actual':y_nomulti_test3})
knn
# Out:
#      Predicted  Actual
# 532       12.4       8
# 375       12.8      15
# 306       12.6      16
# 625       12.2      10
# 480       11.8      10
# ..         ...     ...
# 478        6.6       8
# 636       13.2      19
# 632       10.6       9
# 96        11.6      11
# 350        8.8      11
#
# [195 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS 70-30 SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_nomulti_test3,y_pred3))
# Out:
# MAE: 2.2728205128205126
# RMSE: 3.0368674818905257
# R2 score: 0.06076448405896473

# %%
plt.scatter(x_nomulti_test3['absences'], y_nomulti_test3, label='Test Data')
plt.scatter(x_nomulti_test3['absences'], y_pred3, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# # 60-40 SPLIT

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(x_nomulti_train4, y_nomulti_train4)
y_pred4 = model.predict(x_nomulti_test4)

# %%
knn = pd.DataFrame({'Predicted':y_pred4,'Actual':y_nomulti_test4})
knn
# Out:
#      Predicted  Actual
# 532       12.2       8
# 375       12.8      15
# 306       12.4      16
# 625       12.2      10
# 480       13.8      10
# ..         ...     ...
# 140       12.6      10
# 587       11.8       8
# 225        9.8      12
# 536       11.6      14
# 605       12.6       0
#
# [260 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS 60-40 SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_nomulti_test4,y_pred4))
# Out:
# MAE: 2.3953846153846157
# RMSE: 3.2622314213056445
# R2 score: 0.06576369617077316

# %%
plt.scatter(x_nomulti_test4['absences'], y_nomulti_test4, label='Test Data')
plt.scatter(x_nomulti_test4['absences'], y_pred4, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVR
model = SVR(kernel='linear')

# %% [markdown]
# # 80-20 SPLIT

# %%
model.fit(x_nomulti_train1, y_nomulti_train1)
y_pred1=model.predict(x_nomulti_test1)

# %%
svm = pd.DataFrame({'Predicted':y_pred2,'Actual':y_nomulti_test2})
svm
# Out:
#      Predicted  Actual
# 532       13.2       8
# 375       13.0      15
# 306       12.6      16
# 625       12.0      10
# 480       12.2      10
# ..         ...     ...
# 588       14.2       9
# 332       14.4      18
# 202       13.2      14
# 316       13.8      16
# 90        11.8      11
#
# [163 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS 80-20 SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test1,y_pred1))
# Out:
# MAE: 1.7353699618873997
# RMSE: 2.4647437557965755
# R2 score: 0.14484195615899487

# %%
plt.scatter(x_nomulti_test1['absences'], y_nomulti_test1, label='Test Data')
plt.scatter(x_nomulti_test1['absences'], y_pred1, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# # 75-25 SPLIT

# %%
model.fit(x_nomulti_train2, y_nomulti_train2)
y_pred2=model.predict(x_nomulti_test2)

# %%
svm = pd.DataFrame({'Predicted':y_pred3,'Actual':y_nomulti_test3})
svm
# Out:
#      Predicted  Actual
# 532       12.4       8
# 375       12.8      15
# 306       12.6      16
# 625       12.2      10
# 480       11.8      10
# ..         ...     ...
# 478        6.6       8
# 636       13.2      19
# 632       10.6       9
# 96        11.6      11
# 350        8.8      11
#
# [195 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS 75-25 SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test2,y_pred2))
# Out:
# MAE: 1.8857244301714273
# RMSE: 2.7274879527939317
# R2 score: 0.17579811825358915

# %%
plt.scatter(x_nomulti_test2['absences'], y_nomulti_test2, label='Test Data')
plt.scatter(x_nomulti_test2['absences'], y_pred2, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# # 70-30 SPLIT

# %%
model.fit(x_nomulti_train3, y_nomulti_train3)
y_pred3=model.predict(x_nomulti_test3)

# %%
svm = pd.DataFrame({'Predicted':y_pred3,'Actual':y_nomulti_test3})
svm
# Out:
#      Predicted  Actual
# 532  11.078122       8
# 375  13.678024      15
# 306  12.760946      16
# 625  11.083191      10
# 480   9.083550      10
# ..         ...     ...
# 478   6.483681       8
# 636  13.927698      19
# 632   8.848494       9
# 96   11.465219      11
# 350   9.710887      11
#
# [195 rows x 2 columns]

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_nomulti_test3,y_pred3))
# Out:
# MAE: 1.9278325176811137
# RMSE: 2.758299007474903
# R2 score: 0.22517163638912718

# %%
plt.scatter(x_nomulti_test3['absences'], y_nomulti_test3, label='Test Data')
plt.scatter(x_nomulti_test3['absences'], y_pred3, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# # 60-40 SPLIT

# %%
model.fit(x_nomulti_train4, y_nomulti_train4)
y_pred4=model.predict(x_nomulti_test4)

# %%
svm = pd.DataFrame({'Predicted':y_pred4,'Actual':y_nomulti_test4})
svm
# Out:
#      Predicted  Actual
# 532  11.492881       8
# 375  13.272911      15
# 306  13.266434      16
# 625  10.920855      10
# 480   8.729900      10
# ..         ...     ...
# 140  10.835391      10
# 587  10.346668       8
# 225  11.292561      12
# 536  12.808947      14
# 605   9.574411       0
#
# [260 rows x 2 columns]

# %% [markdown]
# EVALUATION METRICS 60-40 SPLIT

# %%
print("MAE:",metrics.mean_absolute_error(y_nomulti_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_nomulti_test4,y_pred4))
# Out:
# MAE: 2.1746416089974523
# RMSE: 3.125548826195848
# R2 score: 0.14240985411413698

# %%
plt.scatter(x_nomulti_test4['absences'], y_nomulti_test4, label='Test Data')
plt.scatter(x_nomulti_test4['absences'], y_pred4, color='red', linewidth=1, label='KNN points')
plt.xlabel('absences')
plt.ylabel('G3')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# # DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# # 80-20 SPLIT

# %%
reg1 = DecisionTreeRegressor()
reg1.fit(x_nomulti_train1,y_nomulti_train1)
y_pred1 = reg1.predict(x_nomulti_test1)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test1,y_pred1))
# Out:
# MAE: 2.5115384615384615
# RMSE: 3.3800887562311144
# R2 score: -0.6082703071899778

# %% [markdown]
# # 75-25 SPLIT

# %%
reg2 = DecisionTreeRegressor()
reg2.fit(x_nomulti_train2,y_nomulti_train2)
y_pred2 = reg2.predict(x_nomulti_test2)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test2,y_pred2))
# Out:
# MAE: 2.6196319018404908
# RMSE: 3.636049902807375
# R2 score: -0.46476377131896096

# %% [markdown]
# # 70-30 SPLIT

# %%
reg3 = DecisionTreeRegressor()
reg3.fit(x_nomulti_train3,y_nomulti_train3)
y_pred3 = reg3.predict(x_nomulti_test3)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_nomulti_test3,y_pred3))
# Out:
# MAE: 2.787179487179487
# RMSE: 3.860882056785762
# R2 score: -0.5180843171494687

# %% [markdown]
# # 60-40 SPLIT

# %%
reg1 = DecisionTreeRegressor()
reg1.fit(x_nomulti_train4,y_nomulti_train4)
y_pred4 = reg1.predict(x_nomulti_test4)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_nomulti_test4,y_pred4))
# Out:
# MAE: 2.746153846153846
# RMSE: 3.8247674640226372
# R2 score: -0.2842136429924771

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %% [markdown]
# # 80-20 SPLIT

# %%
rf.fit(x_nomulti_train1,y_nomulti_train1)
y_pred1=rf.predict(x_nomulti_test1)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test1, y_pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test1,y_pred1))
# Out:
# MAE: 1.8209448717948717
# RMSE: 2.4506397081728486
# R2 score: 0.15460092665321

# %% [markdown]
# # 75-25 SPLIT

# %%
rf.fit(x_nomulti_train2,y_nomulti_train2)
y_pred2=rf.predict(x_nomulti_test2)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test2, y_pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test2,y_pred2))
# Out:
# MAE: 2.0222852760736196
# RMSE: 2.7471695948229766
# R2 score: 0.16386026581008561

# %% [markdown]
# # 70-30 SPLIT

# %%
rf.fit(x_nomulti_train3,y_nomulti_train3)
y_pred3=rf.predict(x_nomulti_test3)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test3, y_pred3)))
print("R2 score:",metrics.r2_score(y_nomulti_test3,y_pred3))
# Out:
# MAE: 2.1353410256410257
# RMSE: 2.8063595222189046
# R2 score: 0.19793523277808422

# %% [markdown]
# # 60-40 SPLIT

# %%
rf.fit(x_nomulti_train4,y_nomulti_train4)
y_pred4=rf.predict(x_nomulti_test4)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test4, y_pred4)))
print("R2 score:",metrics.r2_score(y_nomulti_test4,y_pred4))
# Out:
# MAE: 2.2387229853479855
# RMSE: 3.0311931902347986
# R2 score: 0.19340701618315526

# %% [markdown]
# # XG BOOST

# %% [markdown]
# # 80-20 SPLIT

# %%
model1 = xgb.XGBRegressor()
model2 = xgb.XGBRegressor(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(x_nomulti_train1, y_nomulti_train1)
train_model2 = model2.fit(x_nomulti_train1, y_nomulti_train1)

# %%
pred1 = train_model1.predict(x_nomulti_test1)
pred2 = train_model2.predict(x_nomulti_test1)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test1,pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test1, pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test1,pred1))
print("MAE:",metrics.mean_absolute_error(y_nomulti_test1,pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test1, pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test1,pred2))
# Out:
# MAE: 2.083401738680326
# RMSE: 2.7170013746779493
# R2 score: -0.03916037082672119
# MAE: 1.9762868826205915
# RMSE: 2.6211952635027016
# R2 score: 0.03283274173736572

# %% [markdown]
# # 75-25 SPLIT

# %%
model1 = xgb.XGBRegressor()
model2 = xgb.XGBRegressor(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(x_nomulti_train2, y_nomulti_train2)
train_model2 = model2.fit(x_nomulti_train2, y_nomulti_train2)

# %%
pred1 = train_model1.predict(x_nomulti_test2)
pred2 = train_model2.predict(x_nomulti_test2)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test2,pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test2, pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test2,pred1))
print("MAE:",metrics.mean_absolute_error(y_nomulti_test2,pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test2, pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test2,pred2))
# Out:
# MAE: 2.2456787729555843
# RMSE: 2.945913200195567
# R2 score: 0.038503289222717285
# MAE: 2.103085557375949
# RMSE: 2.8952160027226785
# R2 score: 0.07131189107894897

# %% [markdown]
# # 70-30 SPLIT

# %%
model1 = xgb.XGBRegressor()
model2 = xgb.XGBRegressor(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(x_nomulti_train3, y_nomulti_train3)
train_model2 = model2.fit(x_nomulti_train3, y_nomulti_train3)

# %%
pred1 = train_model1.predict(x_nomulti_test3)
pred2 = train_model2.predict(x_nomulti_test3)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test3,pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test3, pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test3,pred1))
print("MAE:",metrics.mean_absolute_error(y_nomulti_test3,pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test3, pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test3,pred2))
# Out:
# MAE: 2.435498350094526
# RMSE: 3.1075748564511168
# R2 score: 0.016518771648406982
# MAE: 2.1946773590185704
# RMSE: 2.951054955626062
# R2 score: 0.1130942702293396

# %% [markdown]
# # 60-40 SPLIT

# %%
model1 = xgb.XGBRegressor()
model2 = xgb.XGBRegressor(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(x_nomulti_train4, y_nomulti_train4)
train_model2 = model2.fit(x_nomulti_train4, y_nomulti_train4)

# %%
pred1 = train_model1.predict(x_nomulti_test4)
pred2 = train_model2.predict(x_nomulti_test4)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test4,pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test4, pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test4,pred1))
print("MAE:",metrics.mean_absolute_error(y_nomulti_test4,pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test4, pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test4,pred2))
# Out:
# MAE: 2.4886041953013494
# RMSE: 3.432591442940631
# R2 score: -0.03435933589935303
# MAE: 2.307413349701808
# RMSE: 3.0932088960968427
# R2 score: 0.1600649356842041

# %% [markdown]
# # ADAboost

# %% [markdown]
# # 80-20 SPLIT

# %%
adaboost = AdaBoostRegressor(estimator=base_estimator, # Changed argument name here
                              n_estimators=3,random_state=0)
adaboost.fit(x_nomulti_train1, y_nomulti_train1)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3, random_state=0),
#                   n_estimators=3, random_state=0)

# %%
y_pred1 = adaboost.predict(x_nomulti_test1)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test1,y_pred1))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test1,y_pred1)))
print("R2 score:",metrics.r2_score(y_nomulti_test1,y_pred1))
# Out:
# MAE: 1.7669767498432174
# RMSE: 2.3749913079505034
# R2 score: 0.205988332553113

# %% [markdown]
# # 75-25 SPLIT

# %%
adaboost = AdaBoostRegressor(estimator=base_estimator, # Changed argument name here
                              n_estimators=3,random_state=0)
adaboost.fit(x_nomulti_train2, y_nomulti_train2)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3, random_state=0),
#                   n_estimators=3, random_state=0)

# %%
y_pred2 = adaboost.predict(x_nomulti_test2)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test2,y_pred2))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test2,y_pred2)))
print("R2 score:",metrics.r2_score(y_nomulti_test2,y_pred2))
# Out:
# MAE: 1.930049549609004
# RMSE: 2.674186681702173
# R2 score: 0.2076968860267927

# %% [markdown]
# # 70-30 SPLIT

# %%
adaboost = AdaBoostRegressor(estimator=base_estimator, # Changed argument name here
                              n_estimators=3,random_state=0)
adaboost.fit(x_nomulti_train3, y_nomulti_train3)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3, random_state=0),
#                   n_estimators=3, random_state=0)

# %%
y_pred3 = adaboost.predict(x_nomulti_test3)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test3,y_pred3))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test3,y_pred3)))
print("R2 score:",metrics.r2_score(y_nomulti_test3,y_pred3))
# Out:
# MAE: 2.020332470590654
# RMSE: 2.74043785389029
# R2 score: 0.2351738302137818

# %% [markdown]
# # 60-40 SPLIT

# %%
adaboost = AdaBoostRegressor(estimator=base_estimator, # Changed argument name here
                              n_estimators=3,random_state=0)
adaboost.fit(x_nomulti_train4, y_nomulti_train4)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3, random_state=0),
#                   n_estimators=3, random_state=0)

# %%
y_pred4 = adaboost.predict(x_nomulti_test4)
print("MAE:",metrics.mean_absolute_error(y_nomulti_test4,y_pred4))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_nomulti_test4,y_pred4)))
print("R2 score:",metrics.r2_score(y_nomulti_test4,y_pred4))
# Out:
# MAE: 2.131547000869037
# RMSE: 2.8561443254512486
# R2 score: 0.28387719311087434

# %% [markdown]
# # ANN

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 80-20 SPLIT

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([
                            tf.keras.layers.Dense(24),

                            tf.keras.layers.Dense(23),

                            tf.keras.layers.Dense(22),

                            tf.keras.layers.Dense(21),

                            tf.keras.layers.Dense(20),

                            tf.keras.layers.Dense(10),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam
# Set the learning rate when creating the Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss= tf.keras.losses.mae,
              optimizer= optimizer,  # Use the optimizer with the specified learning rate
              metrics= ["mae"])

# STEP3: Fit the model
# Remove learning_rate from fit() arguments
history= model.fit(x_nomulti_train1, y_nomulti_train1, epochs= 120, verbose=1)
# Out:
# Epoch 1/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 10.5008 - mae: 10.5008
# Epoch 2/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1186 - mae: 7.1186
# Epoch 3/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7338 - mae: 4.7338
# Epoch 4/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7928 - mae: 3.7928
# Epoch 5/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3238 - mae: 3.3238
# Epoch 6/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0503 - mae: 3.0503
# Epoch 7/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9028 - mae: 2.9028
# Epoch 8/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7165 - mae: 2.7165
# Epoch 9/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6343 - mae: 2.6343
# Epoch 10/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5107 - mae: 2.5107
# Epoch 11/120
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4721 - mae: 2.4721
# Epoch 12/120
# ...

# %%
model.evaluate(x_nomulti_test1, y_nomulti_test1)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9271 - mae: 1.9271
# [1.8231391906738281, 1.8231391906738281]

# %%
model.summary();
# Out:
# Model: "sequential_87"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_543 (Dense)                    │ (None, 24)                  │             600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_544 (Dense)                    │ (None, 23)                  │             575 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_545 (Dense)                    │ (None, 22)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_546 (Dense)                    │ (None, 21)                  │             483 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# # 75-25 SPLIT

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([
 tf.keras.layers.Dense(60),

                            tf.keras.layers.Dense(30),

                            tf.keras.layers.Dense(20),

                            tf.keras.layers.Dense(15),

                            tf.keras.layers.Dense(10),

                            tf.keras.layers.Dense(5),

                            tf.keras.layers.Dense(3),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam
# Set the learning rate when creating the Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss= tf.keras.losses.mae,
              optimizer= optimizer,  # Use the optimizer with the specified learning rate
              metrics= ["mae"])

# STEP3: Fit the model
# Remove learning_rate from fit() arguments
history= model.fit(x_nomulti_train2, y_nomulti_train2, epochs= 120, verbose=1)
# Out:
# Epoch 1/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 8.6477 - mae: 8.6477
# Epoch 2/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1830 - mae: 6.1830
# Epoch 3/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8772 - mae: 3.8772
# Epoch 4/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3479 - mae: 3.3479
# Epoch 5/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9280 - mae: 2.9280
# Epoch 6/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9023 - mae: 2.9023
# Epoch 7/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8870 - mae: 2.8870
# Epoch 8/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8762 - mae: 2.8762
# Epoch 9/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8839 - mae: 2.8839
# Epoch 10/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8103 - mae: 2.8103
# Epoch 11/120
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6733 - mae: 2.6733
# Epoch 12/120
# ...

# %%
model.evaluate(x_nomulti_train2, y_nomulti_train2)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2642 - mae: 2.2642
# [2.093324661254883, 2.093324661254883]

# %%
model.summary();
# Out:
# Model: "sequential_88"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_550 (Dense)                    │ (None, 60)                  │           1,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_551 (Dense)                    │ (None, 30)                  │           1,830 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_552 (Dense)                    │ (None, 20)                  │             620 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_553 (Dense)                    │ (None, 15)                  │             315 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# # 70-30 SPLIT

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([
                             tf.keras.layers.Dense(60),

                            tf.keras.layers.Dense(30),

                            tf.keras.layers.Dense(20),

                            tf.keras.layers.Dense(15),

                            tf.keras.layers.Dense(10),

                            tf.keras.layers.Dense(5),

                            tf.keras.layers.Dense(3),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam
# Set the learning rate when creating the Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss= tf.keras.losses.mae,
              optimizer= optimizer,  # Use the optimizer with the specified learning rate
              metrics= ["mae"])

# STEP3: Fit the model
# Remove learning_rate from fit() arguments
history= model.fit(x_nomulti_train3, y_nomulti_train3, epochs= 120, verbose=1)
# Out:
# Epoch 1/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 11.7163 - mae: 11.7163
# Epoch 2/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7029 - mae: 6.7029
# Epoch 3/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0823 - mae: 4.0823
# Epoch 4/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3887 - mae: 3.3887
# Epoch 5/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8997 - mae: 2.8997
# Epoch 6/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7331 - mae: 2.7331
# Epoch 7/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6593 - mae: 2.6593
# Epoch 8/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7643 - mae: 2.7643
# Epoch 9/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7430 - mae: 2.7430
# Epoch 10/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.6124 - mae: 2.6124
# Epoch 11/120
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4294 - mae: 2.4294
# Epoch 12/120
# ...

# %%
model.evaluate(x_nomulti_train3, y_nomulti_train3)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.1709 - mae: 2.1709
# [2.022794008255005, 2.022794008255005]

# %%
model.summary();
# Out:
# Model: "sequential_89"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_558 (Dense)                    │ (None, 60)                  │           1,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_559 (Dense)                    │ (None, 30)                  │           1,830 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_560 (Dense)                    │ (None, 20)                  │             620 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_561 (Dense)                    │ (None, 15)                  │             315 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# # 60-40 SPLIT

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model= tf.keras.Sequential([
                            tf.keras.layers.Dense(24),

                            tf.keras.layers.Dense(23),

                            tf.keras.layers.Dense(22),

                            tf.keras.layers.Dense(21),

                            tf.keras.layers.Dense(20),

                            tf.keras.layers.Dense(10),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model   # optimizer can be SGD, Adam
# Set the learning rate when creating the Adam optimizer
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(loss= tf.keras.losses.mae,
              optimizer= optimizer,  # Use the optimizer with the specified learning rate
              metrics= ["mae"])

# STEP3: Fit the model
# Remove learning_rate from fit() arguments
history= model.fit(x_nomulti_train4, y_nomulti_train4, epochs= 120, verbose=1)
# Out:
# Epoch 1/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 10.8388 - mae: 10.8388
# Epoch 2/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2888 - mae: 7.2888
# Epoch 3/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2187 - mae: 6.2187
# Epoch 4/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4995 - mae: 4.4995
# Epoch 5/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5477 - mae: 3.5477
# Epoch 6/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2931 - mae: 3.2931
# Epoch 7/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0711 - mae: 3.0711
# Epoch 8/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9756 - mae: 2.9756
# Epoch 9/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8835 - mae: 2.8835
# Epoch 10/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7581 - mae: 2.7581
# Epoch 11/120
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7073 - mae: 2.7073
# Epoch 12/120
# ...

# %%
model.evaluate(x_nomulti_train4, y_nomulti_train4)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9178 - mae: 1.9178
# [1.8934483528137207, 1.8934483528137207]

# %%
model.summary();
# Out:
# Model: "sequential_90"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_566 (Dense)                    │ (None, 24)                  │             600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_567 (Dense)                    │ (None, 23)                  │             575 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_568 (Dense)                    │ (None, 22)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_569 (Dense)                    │ (None, 21)                  │             483 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')
